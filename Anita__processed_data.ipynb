# %%
# Importing necessary libraries
from sklearn.feature_selection import VarianceThreshold
import pandas as pd

# Step 1: Load the dataset
# Provide the file path to your dataset
file_path = "/content/RegresiUTSTelkom.csv"
try:
    data = pd.read_csv(file_path)
    print("Dataset successfully loaded!")
except FileNotFoundError:
    print(f"File not found at {file_path}. Please check the file path and try again.")
    exit()

# Step 2: Rename columns to x1, x2, ..., xn
column_names = [f'x{i+1}' for i in range(data.shape[1])]
data.columns = column_names  # Ensure column renaming is clean
print("Columns renamed successfully to:", column_names)

# Show basic info and first few rows
print("Dataset Information:")
print(data.info())
print("\nFirst five rows:")
print(data.head())

# Descriptive statistics
print("\nDescriptive statistics:")
print(data.describe())

# Step 3: Drop duplicate rows (if not done already)
data = data.drop_duplicates()
print(f"Duplicates removed. Data now has {data.shape[0]} rows and {data.shape[1]} columns.")

# Step 4: Remove Target Column (Assuming target is 'x1') for Feature Selection
try:
    target = data['x1']
    data = data.drop(columns=['x1'])
    print("Target column 'x1' successfully separated.")
except KeyError:
    print("Target column 'x1' not found in the dataset.")
    exit()

# Step 5: Identifying and Removing Low Correlation Features with Target
# ----> Convert all columns to numeric, errors='coerce' will replace non-numeric values with NaN
for column in data.columns:
    data[column] = pd.to_numeric(data[column], errors='coerce')
target = pd.to_numeric(target, errors='coerce')

# -----> Drop rows with NaN values to avoid issues in correlation calculation
data = data.dropna()
target = target.dropna()


correlation_threshold = 0.1  # Threshold for correlation
correlation_with_target = data.corrwith(target).abs()  # Correlation with target
selected_features = correlation_with_target[correlation_with_target > correlation_threshold].index

# ... rest of your code ...
# ... (previous code) ...

# Step 6: Variance Threshold to Remove Low Variance Features
variance_threshold = 0.1  # Threshold for variance
selector = VarianceThreshold(threshold=variance_threshold)

# Create data_selected using selected_features from correlation analysis
data_selected = data[selected_features]  # Selecting the columns based on correlation

try:
    data_high_variance = selector.fit_transform(data_selected)
    print("Low variance features removed.")
except ValueError:
    print("Error: No feature met the variance threshold. Adjust the threshold and try again.")
    exit()

# ... (rest of the code) ...

# Step 7: Add the target column back to the processed data
data_final['x1'] = target.values[:data_final.shape[0]]  # Adjusting if rows were dropped during processing
print("Target column added back to the processed data.")

# Step 8: Save the processed dataset
processed_file_path = "/content/RegresiUTSTelkom.csv"
try:
    data_final.to_csv(processed_file_path, index=False)
    print("Processed dataset saved successfully!")
    print("Processed dataset saved as:", processed_file_path)
except Exception as e:
    print(f"Error saving the processed dataset: {e}")

# Final output message
print(f"Final dataset shape: {data_final.shape}")
# Out:
# Dataset successfully loaded!
# Columns renamed successfully to: ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49', 'x50', 'x51', 'x52', 'x53', 'x54', 'x55', 'x56', 'x57', 'x58', 'x59', 'x60', 'x61', 'x62', 'x63', 'x64', 'x65', 'x66', 'x67', 'x68', 'x69', 'x70', 'x71', 'x72', 'x73', 'x74', 'x75', 'x76', 'x77', 'x78', 'x79', 'x80', 'x81', 'x82', 'x83', 'x84', 'x85', 'x86', 'x87', 'x88', 'x89', 'x90', 'x91']
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71907 entries, 0 to 71906
# Data columns (total 91 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1
-0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 1  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 2 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 3  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
# 4  -5.19943   3.63566  ...   6.59753  -50.69577  26.02574  18.94430  -0.33730
#
#         x87        x88       x89        x90       x91
# 0 -32.22788   70.49388  12.04941   58.43453  26.92061
# 1  43.20130 -115.00698  -0.05859   39.67068  -0.66345
# 2  82.58061  -72.08993   9.90558  199.62971  18.85382
# 3  -7.50035   51.76631   7.88713   55.66926  28.74903
# 4   6.09352   35.18381   5.00283  -11.02257   0.02263
#
# [5 rows x 91 columns]
#
# Descriptive statistics:
#                  x1            x2            x3            x4            x5  \
# count  71907.000000  71907.000000  71907.000000  71907.000000  71907.000000
# mean    1998.201163     43.364917      1.818269      8.597675      1.277579
# std       10.859975      6.027611     50.688704     35.220035     16.424891
# min     1922.000000      4.418500   -284.908360   -257.525600   -120.723150
# 25%     1994.000000     39.971505    -25.546215    -11.500915     -8.536260
# 50%     2002.000000     44.166500      8.737310     10.297690     -0.523360
# 75%     2006.000000     47.780045     36.250580     29.694595      8.993335
# max     2010.000000     58.196280    304.266390    260.150700    155.737220
#
#                  x6            x7            x8            x9           x10  \
# count  71907.000000  71907.000000  71907.000000  71907.000000  71907.000000
# mean      -6.611888     -9.418147     -2.454750     -1.920075      3.872047
# std       22.597464     12.988343     14.458931      7.968129     10.560283
# min     -181.953370    -65.498170   -165.322690    -62.412130   -126.479040
# 25%      -20.607095    -18.433185    -10.774715     -6.611180     -2.168105
# 50%       -6.021350    -11.080750     -1.991800     -1.885820      3.882810
# 75%        7.715145     -2.189170      6.477760      2.790120     10.006625
# max      262.068870    119.815590    121.211920     77.730830     86.752810
#
#        ...           x82           x83           x84           x85  \
# count  ...  71906.000000  71906.000000  71906.000000  71906.000000
# mean   ...     16.036824    -73.197754     41.050337     39.481313
# std    ...     31.912089    174.296144    122.502585     96.077145
# min    ...   -424.517570  -2334.760570  -1324.180160  -1412.660510
# 25%    ...     -1.612357   -138.712605    -21.637285     -4.467700
# 50%    ...      9.403105    -52.788460     28.422400     34.057585
# 75%    ...     26.480767     13.607917     89.015178     78.811747
# max    ...    587.732680   1959.231200   2758.579760   1482.642140
#
#                 x86           x87           x88           x89           x90  \
# count  71906.000000  71906.000000  71906.000000  71906.000000  71906.000000
# mean       0.388499     17.431404    -22.698569      4.405813     18.674040
# std       15.915033    113.173815    174.779578     13.313437    189.226613
# min     -198.622200  -2343.894110  -3026.006600   -233.456480  -5000.654060
# 25%       -6.658175    -32.206065   -100.057952     -2.626397    -61.770782
# 50%        0.818985     14.952950    -18.975395      3.088365      6.926645
# 75%        8.398038     67.389335     55.026637      9.915588     85.350377
# max      198.180750   1181.789560   2833.608950    229.888800   5289.111380
#
#                 x91
# count  71906.000000
# mean       1.557400
# std       22.157698
# min     -318.223330
# 25%       -8.778105
# 50%        0.151165
# 75%        9.973167
# max      378.662140
#
# [8 rows x 91 columns]
# Duplicates removed. Data now has 71878 rows and 91 columns.
# Target column 'x1' successfully separated.
# Low variance features removed.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7fad2798e983> in <cell line: 78>()
#      76
#      77 # Step 7: Add the target column back to the processed data
# ---> 78 data_final['x1'] = target.values[:data_final.shape[0]]  # Adjusting if rows were dropped during processing
#      79 print("Target column added back to the processed data.")
#      80
#
# NameError: name 'data_final' is not defined

# %%
# Importing necessary libraries
from sklearn.feature_selection import VarianceThreshold
import pandas as pd

# Step 1: Load the dataset
# Provide the file path to your dataset
file_path = "/content/RegresiUTSTelkom.csv"
try:
    data = pd.read_csv(file_path)
    print("Dataset successfully loaded!")
except FileNotFoundError:
    print(f"File not found at {file_path}. Please check the file path and try again.")
    exit()

# Step 2: Rename columns to x1, x2, ..., xn
column_names = [f'x{i+1}' for i in range(data.shape[1])]
data.columns = column_names  # Ensure column renaming is clean
print("Columns renamed successfully to:", column_names)

# Show basic info and first few rows
print("Dataset Information:")
print(data.info())
print("\nFirst five rows:")
print(data.head())

# Descriptive statistics
print("\nDescriptive statistics:")
print(data.describe())

# Step 3: Drop duplicate rows (if not done already)
data = data.drop_duplicates()
print(f"Duplicates removed. Data now has {data.shape[0]} rows and {data.shape[1]} columns.")

# Step 4: Remove Target Column (Assuming target is 'x1') for Feature Selection
try:
    target = data['x1']
    data = data.drop(columns=['x1'])
    print("Target column 'x1' successfully separated.")
except KeyError:
    print("Target column 'x1' not found in the dataset.")
    exit()

# Step 5: Identifying and Removing Low Correlation Features with Target
# ----> Convert all columns to numeric, errors='coerce' will replace non-numeric values with NaN
for column in data.columns:
    data[column] = pd.to_numeric(data[column], errors='coerce')
target = pd.to_numeric(target, errors='coerce')

# -----> Drop rows with NaN values to avoid issues in correlation calculation
data = data.dropna()
target = target.dropna()


correlation_threshold = 0.1  # Threshold for correlation
correlation_with_target = data.corrwith(target).abs()  # Correlation with target
selected_features = correlation_with_target[correlation_with_target > correlation_threshold].index

# ... rest of your code ...
# ... (previous code) ...

# Step 6: Variance Threshold to Remove Low Variance Features
variance_threshold = 0.1  # Threshold for variance
selector = VarianceThreshold(threshold=variance_threshold)

# Create data_selected using selected_features from correlation analysis
data_selected = data[selected_features]  # Selecting the columns based on correlation

try:
    data_high_variance = selector.fit_transform(data_selected)
    print("Low variance features removed.")
except ValueError:
    print("Error: No feature met the variance threshold. Adjust the threshold and try again.")
    exit()

# Create a DataFrame from the transformed data to retain column names
# Assign to data_final
data_final = pd.DataFrame(data_high_variance, columns=selected_features[selector.get_support(indices=True)]) # Create data_final here

# ... (rest of the code) ...

# Step 7: Add the target column back to the processed data
data_final['x1'] = target.values[:data_final.shape[0]]  # Adjusting if rows were dropped during processing
print("Target column added back to the processed data.")

# Step 8: Save the processed dataset
processed_file_path = "/content/RegresiUTSTelkom.csv"
try:
    data_final.to_csv(processed_file_path, index=False)
    print("Processed dataset saved successfully!")
    print("Processed dataset saved as:", processed_file_path)
except Exception as e:
    print(f"Error saving the processed dataset: {e}")
# Out:
# Dataset successfully loaded!
# Columns renamed successfully to: ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49', 'x50', 'x51', 'x52', 'x53', 'x54', 'x55', 'x56', 'x57', 'x58', 'x59', 'x60', 'x61', 'x62', 'x63', 'x64', 'x65', 'x66', 'x67', 'x68', 'x69', 'x70', 'x71', 'x72', 'x73', 'x74', 'x75', 'x76', 'x77', 'x78', 'x79', 'x80', 'x81', 'x82', 'x83', 'x84', 'x85', 'x86', 'x87', 'x88', 'x89', 'x90', 'x91']
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79224 entries, 0 to 79223
# Data columns (total 91 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1
2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
# 4  2001  50.54767   0.31568  92.35066  22.38696 -25.51870 -19.04928  20.67345
#
#          x9       x10  ...       x82        x83       x84       x85       x86  \
# 0  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 1  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 2 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 3  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
# 4  -5.19943   3.63566  ...   6.59753  -50.69577  26.02574  18.94430  -0.33730
#
#         x87        x88       x89        x90       x91
# 0 -32.22788   70.49388  12.04941   58.43453  26.92061
# 1  43.20130 -115.00698  -0.05859   39.67068  -0.66345
# 2  82.58061  -72.08993   9.90558  199.62971  18.85382
# 3  -7.50035   51.76631   7.88713   55.66926  28.74903
# 4   6.09352   35.18381   5.00283  -11.02257   0.02263
#
# [5 rows x 91 columns]
#
# Descriptive statistics:
#                  x1            x2            x3            x4            x5  \
# count  79224.000000  79224.000000  79224.000000  79224.000000  79224.000000
# mean    1998.207715     43.372412      1.931209      8.784642      1.245488
# std       10.800431      6.040738     50.912016     35.184292     16.376075
# min     1922.000000      4.418500   -289.862570   -257.525600   -120.723150
# 25%     1994.000000     39.960938    -25.608338    -11.293418     -8.568083
# 50%     2002.000000     44.176055      8.884780     10.444345     -0.562030
# 75%     2006.000000     47.810293     36.638190     29.785857      8.927495
# max     2010.000000     58.196280    304.266390    260.150700    155.737220
#
#                  x6            x7            x8            x9           x10  \
# count  79224.000000  79224.000000  79224.000000  79224.000000  79224.000000
# mean      -6.807013     -9.392580     -2.429650     -1.866605      3.896266
# std       22.623690     13.007888     14.448498      7.952149     10.567215
# min     -181.953370    -65.498170   -165.322690    -62.412130   -126.479040
# 25%      -20.828592    -18.429792    -10.715772     -6.530045     -2.151698
# 50%       -6.216185    -11.095425     -1.961510     -1.816595      3.933235
# 75%        7.558015     -2.200950      6.488593      2.818680     10.051360
# max      262.068870    119.815590    121.211920     77.730830     86.752810
#
#        ...           x82           x83           x84           x85  \
# count  ...  79224.000000  79224.000000  79224.000000  79224.000000
# mean   ...     16.082377    -74.202523     41.158043     39.522132
# std    ...     31.846103    175.876484    122.167925     95.830823
# min    ...   -424.517570  -2334.760570  -1324.180160  -1412.660510
# 25%    ...     -1.549905   -138.950058    -21.424997     -4.226892
# 50%    ...      9.441955    -52.894210     28.495185     34.050895
# 75%    ...     26.612182     13.184788     89.104478     78.667367
# max    ...    679.146970   1959.231200   2758.579760   1482.642140
#
#                 x86           x87           x88           x89           x90  \
# count  79223.000000  79223.000000  79223.000000  79223.000000  79223.000000
# mean       0.442823     17.691185    -23.039371      4.397792     18.753163
# std       15.895887    112.889019    174.212724     13.279286    188.056658
# min     -198.622200  -2343.894110  -3026.006600   -233.456480  -5000.654060
# 25%       -6.620470    -31.931205   -100.252430     -2.613960    -61.325240
# 50%        0.832050     15.017070    -19.285690      3.068280      6.874860
# 75%        8.407095     67.261620     54.868195      9.870715     85.359990
# max      198.180750   1181.789560   2833.608950    229.888800   5289.111380
#
#                 x91
# count  79223.000000
# mean       1.614110
# std       22.125064
# min     -318.223330
# 25%       -8.711080
# 50%        0.171320
# 75%        9.986150
# max      378.662140
#
# [8 rows x 91 columns]
# Duplicates removed. Data now has 79195 rows and 91 columns.
# Target column 'x1' successfully separated.
# Low variance features removed.
# Target column added back to the processed data.
# Processed dataset saved successfully!
# Processed dataset saved as: /content/RegresiUTSTelkom.csv
